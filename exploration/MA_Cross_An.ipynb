# %%
import pandas as pd
from plotting import CandlePlot
pd.set_option("display.max_columns", None)

# %%
df_ma_res = pd.read_pickle("../data/ma_res.pkl")
df_ma_trades = pd.read_pickle("../data/ma_trades.pkl")

# %%
df_ma_res['granularity'].unique()
# Out:
# array(['H1', 'H4'], dtype=object)

# %%
df_ma_res_h1 = df_ma_res[df_ma_res['granularity'] == "H1"].copy()
df_ma_trades_h1 = df_ma_trades[df_ma_trades['granularity'] == "H1"].copy()

# %%
df_ma_res_h1.columns
# Out:
# Index(['pair', 'num_trades', 'total_gain', 'mean_gain', 'min_gain', 'max_gain',
#        'ma_l', 'ma_s', 'cross', 'granularity'],
#       dtype='object')

# %%
df_cross_summary = df_ma_res_h1[['pair', 'num_trades', 'total_gain','cross']].copy()

# %%
df_cross_summary.head(4)
# Out:
#       pair  num_trades  total_gain        cross
# 0  EUR_USD         205         290  MA_10_MA_20
# 1  EUR_USD         105         243  MA_10_MA_40
# 2  EUR_USD         105        -126  MA_20_MA_40
# 3  EUR_USD         110        -372  MA_30_MA_40

# %%
df_cross_gr = df_cross_summary.groupby(by=['cross'], as_index=False).sum()
df_cross_gr.sort_values(by='total_gain', ascending=False, inplace=True)
df_cross_gr.head(4)
# Out:
#            cross                                               pair  \
# 1   MA_10_MA_150  EUR_USDEUR_GBPGBP_USDEUR_USDEUR_GBPEUR_JPYEUR_...
# 10  MA_30_MA_150  EUR_USDEUR_GBPGBP_USDEUR_USDEUR_GBPEUR_JPYEUR_...
# 6   MA_20_MA_150  EUR_USDEUR_GBPGBP_USDEUR_USDEUR_GBPEUR_JPYEUR_...
# 13  MA_40_MA_120  EUR_USDEUR_GBPGBP_USDEUR_USDEUR_GBPEUR_JPYEUR_...
#
#     num_trades  total_gain
# 1          868        7988
# 10         558        6707
# 6          674        4970
# 13         600        4485

# %%
df_ma_res_h1.head()
# Out:
#       pair  num_trades  total_gain  mean_gain  min_gain  max_gain   ma_l  \
# 0  EUR_USD         205         290          1       -81       157  MA_20
# 1  EUR_USD         105         243          2       -91       229  MA_40
# 2  EUR_USD         105        -126         -1      -127       226  MA_40
# 3  EUR_USD         110        -372         -3      -120       215  MA_40
# 4  EUR_USD          75        -345         -4      -107       267  MA_80
#
#     ma_s        cross granularity
# 0  MA_10  MA_10_MA_20          H1
# 1  MA_10  MA_10_MA_40          H1
# 2  MA_20  MA_20_MA_40          H1
# 3  MA_30  MA_30_MA_40          H1
# 4  MA_10  MA_10_MA_80          H1

# %%
total_pairs = len(df_ma_res_h1['pair'].unique())

# %%
temp = df_ma_res_h1[df_ma_res_h1['cross'] == 'MA_10_MA_150' ]

# %%
temp[temp['total_gain'] > 0]
# Out:
#         pair  num_trades  total_gain  mean_gain  min_gain  max_gain    ma_l  \
# 12   EUR_USD          39         347          8       -79       310  MA_150
# 28   EUR_GBP          52          74          1       -36       115  MA_150
# 44   GBP_USD          46         612         13      -130       413  MA_150
# 108  EUR_USD          39         347          8       -79       310  MA_150
# 124  EUR_GBP          52          74          1       -36       115  MA_150
# 140  EUR_JPY          38        1266         33      -190      1178  MA_150
# 188  USD_JPY          40        1498         37      -268       608  MA_150
# 204  USD_CAD          44         306          6       -63       267  MA_150
# 220  GBP_USD          46         612         13      -130       413  MA_150
# 236  GBP_JPY          50        1322         26      -197      1722  MA_150
# 268  GBP_CAD          43         719         16      -118       392  MA_150
# 284  AUD_USD          50         190          3       -98       245  MA_150
# 300  AUD_JPY          48        1563         32      -109      1080  MA_150
# 332  CAD_JPY          44         503         11      -145       928  MA_150
#
#       ma_s         cross granularity
# 12   MA_10  MA_10_MA_150          H1
# 28   MA_10  MA_10_MA_150          H1
# 44   MA_10  MA_10_MA_150          H1
# 108  MA_10  MA_10_MA_150          H1
# 124  MA_10  MA_10_MA_150          H1
# 140  MA_10  MA_10_MA_150          H1
# 188  MA_10  MA_10_MA_150          H1
# 204  MA_10  MA_10_MA_150          H1
# 220  MA_10  MA_10_MA_150          H1
# 236  MA_10  MA_10_MA_150          H1
# 268  MA_10  MA_10_MA_150          H1
# 284  MA_10  MA_10_MA_150          H1
# 300  MA_10  MA_10_MA_150          H1
# 332  MA_10  MA_10_MA_150          H1

# %%
for c in df_ma_res_h1['cross'].unique():
    temp = df_ma_res_h1[df_ma_res_h1['cross'] == c ]
    pg = temp[temp['total_gain'] > 0].shape[0]
    print(f"{c} pg:{pg}% gain:{(pg / total_pairs) * 100:.0f}%")
# Out:
# MA_10_MA_20 pg:1% gain:33%
# MA_10_MA_40 pg:2% gain:67%
# MA_20_MA_40 pg:1% gain:33%
# MA_30_MA_40 pg:1% gain:33%
# MA_10_MA_80 pg:1% gain:33%
# MA_20_MA_80 pg:1% gain:33%
# MA_30_MA_80 pg:2% gain:67%
# MA_40_MA_80 pg:1% gain:33%
# MA_10_MA_120 pg:3% gain:100%
# MA_20_MA_120 pg:2% gain:67%
# MA_30_MA_120 pg:2% gain:67%
# MA_40_MA_120 pg:2% gain:67%
# MA_10_MA_150 pg:3% gain:100%
# MA_20_MA_150 pg:2% gain:67%
# MA_30_MA_150 pg:2% gain:67%
# MA_40_MA_150 pg:2% gain:67%

# %%
cross = 'MA_10_MA_150'
df_MA_10_MA_150 = df_ma_res_h1[df_ma_res_h1['cross'] == cross]
df_MA_10_MA_150.sort_values(by='total_gain', ascending=False, inplace=True)
# Out:
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_10140\2130372402.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_MA_10_MA_150
# Out:
#         pair  num_trades  total_gain  mean_gain  min_gain  max_gain    ma_l  \
# 300  AUD_JPY          48        1563         32      -109      1080  MA_150
# 188  USD_JPY          40        1498         37      -268       608  MA_150
# 236  GBP_JPY          50        1322         26      -197      1722  MA_150
# 140  EUR_JPY          38        1266         33      -190      1178  MA_150
# 268  GBP_CAD          43         719         16      -118       392  MA_150
# 220  GBP_USD          46         612         13      -130       413  MA_150
# 44   GBP_USD          46         612         13      -130       413  MA_150
# 332  CAD_JPY          44         503         11      -145       928  MA_150
# 108  EUR_USD          39         347          8       -79       310  MA_150
# 12   EUR_USD          39         347          8       -79       310  MA_150
# 204  USD_CAD          44         306          6       -63       267  MA_150
# 284  AUD_USD          50         190          3       -98       245  MA_150
# 28   EUR_GBP          52          74          1       -36       115  MA_150
# 124  EUR_GBP          52          74          1       -36       115  MA_150
# 172  EUR_CAD          53        -156         -2       -97       316  MA_150
# 316  AUD_CAD          64        -225         -3       -64       185  MA_150
# 156  EUR_AUD          61        -392         -6      -111       416  MA_150
# 252  GBP_AUD          59        -672        -11      -113       513  MA_150
#
#       ma_s         cross granularity
# 300  MA_10  MA_10_MA_150          H1
# 188  MA_10  MA_10_MA_150          H1
# 236  MA_10  MA_10_MA_150          H1
# 140  MA_10  MA_10_MA_150          H1
# 268  MA_10  MA_10_MA_150          H1
# 220  MA_10  MA_10_MA_150          H1
# 44   MA_10  MA_10_MA_150          H1
# 332  MA_10  MA_10_MA_150          H1
# 108  MA_10  MA_10_MA_150          H1
# 12   MA_10  MA_10_MA_150          H1
# 204  MA_10  MA_10_MA_150          H1
# 284  MA_10  MA_10_MA_150          H1
# 28   MA_10  MA_10_MA_150          H1
# 124  MA_10  MA_10_MA_150          H1
# 172  MA_10  MA_10_MA_150          H1
# 316  MA_10  MA_10_MA_150          H1
# 156  MA_10  MA_10_MA_150          H1
# 252  MA_10  MA_10_MA_150          H1

# %%
df_gains = df_ma_trades_h1[(df_ma_trades_h1['cross'] == cross) & (df_ma_trades_h1['pair'] == "EUR_USD")].copy()

# %%
df_gains.head(3)
# Out:
#                          time  volume    mid_o    mid_h    mid_l    mid_c  \
# 929 2024-03-20 23:00:00+00:00    2003  1.09321  1.09376  1.09293  1.09376
# 930 2024-03-21 17:00:00+00:00    3007  1.08612  1.08664  1.08560  1.08579
# 931 2024-04-03 16:00:00+00:00    4615  1.08268  1.08363  1.08204  1.08307
#
#        bid_o    bid_h    bid_l    bid_c    ask_o    ask_h    ask_l    ask_c  \
# 929  1.09313  1.09369  1.09285  1.09368  1.09329  1.09383  1.09301  1.09383
# 930  1.08605  1.08656  1.08553  1.08572  1.08620  1.08671  1.08568  1.08586
# 931  1.08260  1.08356  1.08197  1.08300  1.08275  1.08370  1.08211  1.08314
#
#         MA_40     MA_10     MA_80     MA_20    MA_150    MA_120     MA_30  \
# 929  1.086742  1.089794  1.087454  1.087545  1.089447  1.088427  1.087212
# 930  1.089022  1.088901  1.087910  1.091155  1.089225  1.088144  1.090092
# 931  1.076567  1.079177  1.077036  1.078199  1.079007  1.078004  1.077591
#
#         DELTA  DELTA_PREV  TRADE     DIFF  GAIN granularity     pair  GAIN_C  \
# 929  0.000347   -0.000570      1 -0.00797 -79.7          H1  EUR_USD   -79.7
# 930 -0.000324    0.000329     -1 -0.00272  27.2          H1  EUR_USD   -52.5
# 931  0.000170   -0.000461      1 -0.00773 -77.3          H1  EUR_USD  -129.8
#
#        ma_l   ma_s         cross
# 929  MA_150  MA_10  MA_10_MA_150
# 930  MA_150  MA_10  MA_10_MA_150
# 931  MA_150  MA_10  MA_10_MA_150

# %%
cp = CandlePlot(df_gains, candles=False)
cp.show_plot(line_traces=['GAIN_C'])

# %%
for curr in df_MA_10_MA_150[df_MA_10_MA_150.total_gain > 0].pair.unique():
    temp_gains = df_ma_trades_h1[(df_ma_trades_h1.cross==cross)&
                           (df_ma_trades_h1.pair==curr)].copy()
    print(curr, int(temp_gains.GAIN.sum()))
    cp = CandlePlot(temp_gains, candles=False)
    cp.show_plot(line_traces=['GAIN_C'])
# Out:
# AUD_JPY 1563
# USD_JPY 1498
# GBP_JPY 1322
# EUR_JPY 1266
# GBP_CAD 719
# GBP_USD 1224
# CAD_JPY 503
# EUR_USD 695
# USD_CAD 306
# AUD_USD 190
# EUR_GBP 149
